# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("salary_pre.csv")

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
# !pip install scikit-learn

# %%
plt.scatter(df['Experience Years'],df['Salary'])
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.title("EMPlOYEE SALARY WITH EXPERIENCE")
# Out:
# Text(0.5, 1.0, 'EMPlOYEE SALARY WITH EXPERIENCE')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
x=df
x
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
x=df[['Experience Years']]
x
# Out:
#     Experience Years
# 0                1.1
# 1                1.2
# 2                1.3
# 3                1.5
# 4                2.0
# 5                2.2
# 6                2.5
# 7                2.9
# 8                3.0
# 9                3.2
# 10               3.2
# 11               3.5
# 12               3.7
# 13               3.8
# 14               3.9
# 15               4.0
# 16               4.0
# 17               4.1
# 18               4.3
# 19               4.5
# 20               4.7
# 21               4.9
# 22               5.1
# 23               5.3
# 24               5.5
# 25               5.9
# 26               6.0
# 27               6.2
# 28               6.5
# 29               6.8
# 30               7.1
# 31               7.9
# 32               8.2
# 33               8.5
# 34               8.7
# 35               9.0
# 36               9.5
# 37               9.6
# 38              10.3
# 39              10.5

# %%
y= df[["Salary"]]
y
# Out:
#     Salary
# 0    39343
# 1    42774
# 2    46205
# 3    37731
# 4    43525
# 5    39891
# 6    48266
# 7    56642
# 8    60150
# 9    54445
# 10   64445
# 11   60000
# 12   57189
# 13   60200
# 14   63218
# 15   55794
# 16   56957
# 17   57081
# 18   59095
# 19   61111
# 20   64500
# 21   67938
# 22   66029
# 23   83088
# 24   82200
# 25   81363
# 26   93940
# 27   91000
# 28   90000
# 29   91738
# 30   98273
# 31  101302
# 32  113812
# 33  111620
# 34  109431
# 35  105582
# 36  116969
# 37  112635
# 38  122391
# 39  121872

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
m=reg.coef_

# %%
c=reg.intercept_

# %%
m*10.6+c
# Out:
# array([[126623.71113916]])

# %%
b=reg.predict([[10.6]])
b
# Out:
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[126623.71113916]])

# %%
df['predict_y']=reg.predict(x)
df['predict_y']
# Out:
# 0      36149.031319
# 1      37101.396369
# 2      38053.761420
# 3      39958.491522
# 4      44720.316775
# 5      46625.046877
# 6      49482.142029
# 7      53291.602232
# 8      54243.967283
# 9      56148.697384
# 10     56148.697384
# 11     59005.792536
# 12     60910.522638
# 13     61862.887689
# 14     62815.252739
# 15     63767.617790
# 16     63767.617790
# 17     64719.982841
# 18     66624.712942
# 19     68529.443044
# 20     70434.173145
# 21     72338.903247
# 22     74243.633348
# 23     76148.363450
# 24     78053.093551
# 25     81862.553754
# 26     82814.918805
# 27     84719.648907
# 28     87576.744059
# 29     90433.839211
# 30     93290.934363
# 31    100909.854769
# 32    103766.949921
# 33    106624.045074
# 34    108528.775175
# 35    111385.870327
# 36    116147.695581
# 37    117100.060632
# 38    123766.615987
# 39    125671.346088
# Name: predict_y, dtype: float64

# %%
lose=df['Salary']-df['predict_y']
lose
# Out:
# 0      3193.968681
# 1      5672.603631
# 2      8151.238580
# 3     -2227.491522
# 4     -1195.316775
# 5     -6734.046877
# 6     -1216.142029
# 7      3350.397768
# 8      5906.032717
# 9     -1703.697384
# 10     8296.302616
# 11      994.207464
# 12    -3721.522638
# 13    -1662.887689
# 14      402.747261
# 15    -7973.617790
# 16    -6810.617790
# 17    -7638.982841
# 18    -7529.712942
# 19    -7418.443044
# 20    -5934.173145
# 21    -4400.903247
# 22    -8214.633348
# 23     6939.636550
# 24     4146.906449
# 25     -499.553754
# 26    11125.081195
# 27     6280.351093
# 28     2423.255941
# 29     1304.160789
# 30     4982.065637
# 31      392.145231
# 32    10045.050079
# 33     4995.954926
# 34      902.224825
# 35    -5803.870327
# 36      821.304419
# 37    -4465.060632
# 38    -1375.615987
# 39    -3799.346088
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse=mean_squared_error(df['Salary'],df['predict_y'])
mse
# Out:
# 28960383.6537762

# %%
mae=mean_absolute_error(df['Salary'],df['predict_y'])
mae
# Out:
# 4516.281792544623

# %%
reg.score(x,y)
# Out:
# 0.9558814451799361

# %%
# Out:
#   Cell In[99], line 1
#     r2_score(x,reg.df['predict_y])
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)
